# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='SPY_1d_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 956
# --------------------------------------------------
# 90% Confidence Interval: (7.428, 9.1316)
# 95% Confidence Interval: (7.2648, 9.2948)
# 98% Confidence Interval: (7.0751, 9.4845)
# 99% Confidence Interval: (7.0751, 9.4845)
# --------------------------------------------------
# Model Results:
# Model Mean: 8.28%
# Model Std: 16.01%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 10.49%
# Buy/Hold Std: 16.42%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 956
# --------------------------------------------------
# 90% Confidence Interval: (0.6687, 0.7746)
# 95% Confidence Interval: (0.6586, 0.7847)
# 98% Confidence Interval: (0.6468, 0.7965)
# 99% Confidence Interval: (0.6468, 0.7965)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.7216
# Model Std: 0.9952
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8852
# Buy/Hold Std: 0.9236
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is down
# --------------------------------------------------
# --------------------------------------------------
# n = 197
# --------------------------------------------------
# 90% Confidence Interval: (8.7773, 12.5666)
# 95% Confidence Interval: (8.4143, 12.9295)
# 98% Confidence Interval: (7.9923, 13.3515)
# 99% Confidence Interval: (7.9923, 13.3515)
# --------------------------------------------------
# Model Results:
# Model Mean: 10.67%
# Model Std: 16.17%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -14.62%
# Buy/Hold Std: 11.35%
# --------------------------------------------------
# --------------------------------------------------
# n = 197
# --------------------------------------------------
# 90% Confidence Interval: (0.4123, 0.5981)
# 95% Confidence Interval: (0.3945, 0.6159)
# 98% Confidence Interval: (0.3739, 0.6366)
# 99% Confidence Interval: (0.3739, 0.6366)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.5052
# Model Std: 0.7925
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.4631
# Buy/Hold Std: 0.3577
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is up
# --------------------------------------------------
# --------------------------------------------------
# n = 759
# --------------------------------------------------
# 90% Confidence Interval: (6.7082, 8.6096)
# 95% Confidence Interval: (6.5261, 8.7917)
# 98% Confidence Interval: (6.3144, 9.0035)
# 99% Confidence Interval: (6.3144, 9.0035)
# --------------------------------------------------
# Model Results:
# Model Mean: 7.66%
# Model Std: 15.92%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 17.01%
# Buy/Hold Std: 10.0%
# --------------------------------------------------
# --------------------------------------------------
# n = 759
# --------------------------------------------------
# 90% Confidence Interval: (0.7161, 0.8396)
# 95% Confidence Interval: (0.7042, 0.8514)
# 98% Confidence Interval: (0.6905, 0.8652)
# 99% Confidence Interval: (0.6905, 0.8652)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.7778
# Model Std: 1.0345
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.2351
# Buy/Hold Std: 0.6683
# --------------------------------------------------
